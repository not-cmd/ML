# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("/Users/divyeshmedidi/Desktop/wine/canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel("Year")  
plt.ylabel("Per Capita Income (USD)")  
plt.title("Canada")
plt.scatter(df["year"], df["per capita income (US$)"], color='red', marker='.')
plt.plot(df["year"], rg.predict(df[["year"]]),color="blue")

# %%
rg = linear_model.LinearRegression()

# %%
rg.fit(df[["year"]],df["per capita income (US$)"])
# Out:
# LinearRegression()

# %%
rg.predict([[2025]])
# Out:
# /Users/divyeshmedidi/Documents/python programming/ML intro/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45431.01947053])
